# %% [raw]
# Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.
# Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?
# Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.
# Q. 4) Show all the Movies that were released in year 2000.
# Q. 5) Show only the Titles of all TV Shows that were released in India only.
# Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?
# Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".
# Q. 8) In how many movies/shows, Tom Cruise was cast ?
# Q. 9) What are the different Ratings defined by Netflix ?
# Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?
# Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?
# Q. 10) What is the maximum duration of a Movie/Show on Netflix ?
# Q. 11) Which individual country has the Highest No. of TV Shows ?
# Q. 12) How can we sort the dataset by Year ?
# Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %% [markdown]
# ## import pandas

# %%
import pandas as pd

# %% [markdown]
# ## Read csv file

# %%
df=pd.read_csv("C:\\Users\\shrut\\OneDrive\\Desktop\\P_JN\\csv_files\\Netflix.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## lets check shape of dataframe

# %%
df.shape
# Out:
# (7789, 11)

# %% [markdown]
# # lets get columns of dataframe

# %%
for col in df.columns:
    print(col)
# Out:
# Show_Id
# Category
# Title
# Director
# Cast
# Country
# Release_Date
# Rating
# Duration
# Type
# Description

# %% [markdown]
# ## lets get datatype of columns

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ## lets fill null valuen in release date column before object type to datetime convertion

# %%
df['Release_Date']=df['Release_Date'].fillna(df['Release_Date'].mode()[0])

# %% [markdown]
# ## lets convert Release_Date object datatype to datetime datatype

# %%
df['Release_Date']=df['Release_Date'].astype('datetime64[ns]')

# %% [markdown]
# ## lets check datatype after convertion

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %% [markdown]
# ## lets add year column to dataframe

# %%
df['year']=df['Release_Date'].dt.year

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# year                     int32
# dtype: object

# %% [markdown]
# ## 1.Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
duplicate=df.duplicated().sum()

# %%
print(duplicate)
# Out:
# 2

# %% [markdown]
# ### droping the duplicate

# %%
df_new=df.drop_duplicates()

# %% [markdown]
# ## Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
df_new
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df_new.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date       0
# Rating             7
# Duration           0
# Type               0
# Description        0
# year               0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df_new.isna())
# Out:
# <Axes: >

# %% [markdown]
# ## Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
df_new[df_new['Title']=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832   2018-11-02  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  year
# 2832  A ruthless politician will stop at nothing to ...  2018

# %% [markdown]
# ## Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
max_released=df_new['year'].value_counts()
max_released
# Out:
# year
# 2019    2153
# 2020    2019
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: count, dtype: int64

# %%
max_released=df_new['year'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
res=df_new['Category'].value_counts().plot(kind='bar')

# %% [markdown]
# ### using countplot

# %%
sns.countplot(df_new['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %% [markdown]
# ## Q. 4) Show all the Movies that were released in year 2000.

# %%
df_new[(df_new['Category']=='Movie')&( df_new['year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %%
df_new[(df_new['Category']=='Movie')&( df_new['year']==2019)]
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                    Oct-01
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %% [markdown]
# ## Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df_new[(df_new['Category']=='TV Show')& (df_new['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df_new['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Lance Bangs                8
# Name: count, dtype: int64

# %% [markdown]
# ## Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df_new[(df_new['Category']=='Movie')&(df_new['Type']=='Comedies')|(df_new['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ## Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df_new[df_new['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %%
df_new['Cast'].isna().sum() # str contains method does not work with nan value,there fore we have to drop nan value
# Out:
# np.int64(718)

# %%
df2=df_new.dropna()

# %%
df2
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df2[df2['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description  year
# 3860  Through chance, human action, past history and...  2020
# 5071  A fast-talking yuppie is forced to slow down w...  2019

# %% [markdown]
# ## Q. 9) What are the different Ratings defined by Netflix ?

# %%
for rating in df_new['Rating'].unique():
    print(rating)
# Out:
# TV-MA
# R
# PG-13
# TV-14
# TV-PG
# NR
# TV-G
# TV-Y
# nan
# TV-Y7
# PG
# G
# NC-17
# TV-Y7-FV
# UR

# %%
df_new['Rating'].nunique()
# Out:
# 14

# %%
df_new['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
df_new['Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# ## Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df_new[(df_new['Category']=='Movie')&( df_new['Rating']=='TV-14')& (df_new['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# ## Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df_new[(df_new['Category']=='TV Show')&(df_new['Rating']=='R')&( df_new['year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description  year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019

# %% [markdown]
# ## Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
df_new['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### lets split single column to two column , number of minute and another one is uint

# %%
df_new[['minute','unit']]=df_new['Duration'].str.split(" ",expand=True)

# %%
df_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# ### let's check datatype of columns after adding the column

# %%
df_new.dtypes
# Out:
# Show_Id                   object
# Category                  object
# Title                     object
# Director                  object
# Cast                      object
# Country                   object
# Release_Date      datetime64[ns]
# Rating                    object
# Duration                  object
# Type                      object
# Description               object
# year                       int32
# (minute, unit)            object
# minute                    object
# unit                      object
# dtype: object

# %% [markdown]
# ### lets convert minute from object type to int type to find max duration

# %%
df_new['minute']=df_new['minute'].astype(int)

# %% [markdown]
# ### after convertion lets check datatype of columns once again

# %%
df_new.dtypes
# Out:
# Show_Id                   object
# Category                  object
# Title                     object
# Director                  object
# Cast                      object
# Country                   object
# Release_Date      datetime64[ns]
# Rating                    object
# Duration                  object
# Type                      object
# Description               object
# year                       int32
# (minute, unit)            object
# minute                     int64
# unit                      object
# dtype: object

# %% [markdown]
# ### maximum duration is

# %%
print(df_new['minute'].max())
# Out:
# 312

# %% [markdown]
# ## Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
df_show=df_new[df_new['Category']=='TV Show']

# %%
df_show
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df_show['Country'].value_counts()
# Out:
# Country
# United States                                    705
# United Kingdom                                   204
# Japan                                            157
# South Korea                                      147
# India                                             71
#                                                 ...
# United Kingdom, Ireland, United States             1
# United Kingdom, Spain                              1
# Italy, United States                               1
# Japan, Canada                                      1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 183, dtype: int64

# %%
df_show['Country'].value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
# Q. 12) How can we sort the dataset by Year ?

# %%
df_new=df_new.sort_values(by='year',ascending=False)

# %%
df_new
# Out:
#      Show_Id Category                                       Title  \
# 1285   s1286    Movie                                    Charming
# 7572   s7571    Movie                 What's Eating Gilbert Grape
# 72       s73    Movie                                    17 Again
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 4173   s4174  TV Show                                     Monarca
# ...      ...      ...                                         ...
# 3840   s3841    Movie                 Mad Ron's Prevues from Hell
# 5766   s5766    Movie                                    Splatter
# 3248   s3249    Movie                     Just Another Love Story
# 7115   s7114    Movie                        To and From New York
# 1765   s1766  TV Show                             Dinner for Five
#
#                   Director                                               Cast  \
# 1285          Ross Venokur  Wilmer Valderrama, Demi Lovato, Sia, Nia Varda...
# ...

# %%
## Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
first_cond=df_new[(df_new['Category']=='Movie')& (df_new['Type']=='Dramas')|(df_new['Category']=='TV Show')&(df_new['Type']=="Kids' TV")]

# %%
first_cond
# Out:
#      Show_Id Category                                       Title  \
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 4855   s4855    Movie                           Pieces of a Woman
# 2327   s2328  TV Show                           Gabby's Dollhouse
# 1242   s1243    Movie                         Catch Me If You Can
# 422     s423    Movie                            All Together Now
# ...      ...      ...                                         ...
# 308     s309    Movie                    Adam: His Song Continues
# 7364   s7363    Movie                            Unspeakable Acts
# 232     s233    Movie                  A Stoning in Fulham County
# 5833   s5833    Movie                              Strange Voices
# 2962   s2963    Movie                 In Defense of a Married Man
#
#                     Director  \
# 6204        Tony Collingwood
# 4855        Kornél Mundruczó
# 2327                     NaN
# 1242        Steven Spielberg
# ...
